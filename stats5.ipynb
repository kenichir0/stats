# %%
# stats

# %%
#ststs.norm.pdf(x) . stats.norm.cdf(x)

# %%
# nort  正規分布
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

x = np.linspace(-3,3,100)
y = stats.norm.pdf(x)
plt.plot(x,y)

# %%
#CDF  累積

x = np.linspace(-3,3,100)
y = stats.norm.cdf(x)
plt.plot(x,y)

# %%
#正規分布  scale = 標準偏差　ばらつき　loc = 平均
x = np.linspace(-5, 10, 100)

y = stats.norm(loc=2, scale=3).pdf(x)
y2 = stats.norm(loc=3, scale=3).pdf(x)

plt.plot(x,y)
plt.plot(x,y2)

# %%
#カーネル密度推定
x = np.linspace(0.10,10)
y = stats.gaussian_kde([1,1,2,2,3,4,5]).pdf(x)
plt.plot(x,y)

# %%
df=sns.load_dataset('tips')
df['tips rate'] = df['tip'] / df['total_bill']

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  tips rate
# 0         16.99  1.01  Female     No   Sun  Dinner     2   0.059447
# 1         10.34  1.66    Male     No   Sun  Dinner     3   0.160542
# 2         21.01  3.50    Male     No   Sun  Dinner     3   0.166587
# 3         23.68  3.31    Male     No   Sun  Dinner     2   0.139780
# 4         24.59  3.61  Female     No   Sun  Dinner     4   0.146808
# ..          ...   ...     ...    ...   ...     ...   ...        ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3   0.203927
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2   0.073584
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2   0.088222
# 242       17.82  1.75    Male     No   Sat  Dinner     2   0.098204
# 243       18.78  3.00  Female     No  Thur  Dinner     2   0.159744
#
# [244 rows x 8 columns]

# %%
y = stats.gaussian_kde(df['tip']).pdf(x)
plt.plot(x,y)

# %%
sns.displot(df['tip'], kde = True)

# %%
 y3 = stats.gaussian_kde(df['tip']).resample()

# %%
sns.distplot(y3, kde=True)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
rng = np.random.RandomState(10)  # deterministic random data
a = np.hstack((rng.normal(size=1000),
               rng.normal(loc=5, scale=2, size=1000)))
_ = plt.hist(a, bins='auto')  # arguments are passed to np.histogram
plt.title("Histogram with 'auto' bins")
plt.show()

# %%
mg
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/2c/h1l2f09d7fs8kg0wl7jbp_l40000gn/T/ipykernel_1499/2374177644.py in <module>
# ----> 1 mg
#
# NameError: name 'mg' is not defined
